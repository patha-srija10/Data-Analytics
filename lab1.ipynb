# %% [markdown]
# <a href="https://colab.research.google.com/github/patha-srija10/Data-Analytics/blob/main/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Python Library**: Collection of functions & methods that allows to perform lots of actions without writing any code.

# %% [markdown]
# *   Libraries usually contain built-in modules which can be used directly.

# %% [markdown]
#  **Python Analysis libraries are divided into 3 groups:**
#
#
# 1.   **Scientific Computing Libraries:**
#     **Pandas(Data structures and tools)**
# which provide fast access to structured data.
#   **Data Frame:** 2-D table consisting of column and row labels.
# *   It is designed to provide easy indexing functionality.
# **NumPy(Arrayas & Matrices):** Uses arrays for its inputs & outputs.
# *  It can be extended to objects for matrices.
# **SciPy(Integrals, solving differential equations, optimization):** Includes functions for some advanced maths problems as listed and data visualization.
#
# 2. **Visualization Libraries:**
# * Help us create graphs,charts and maps.
# **Matplotlib(plots & graphs):**
# * Highly customizable.
# **Seaborn(heat maps, time series, violin plots):**
# * Based on Matplotlib.
#
# 3. **Algorithmic Libraries:**
# * Solving various algorithms from basic to complex.
# **Scikit-learn:** Contains tools for statistical modeling including Machine Learning: Regression, classification, clustering....
# * Built on NumPy, SciPy & Matplotlib
# **Statsmodels:**
# * Explore data, estimate statistical models and perform statistical tests

# %% [markdown]
# **Importing data:**
# * 2 properties:
# 1. Format: The way data is encoded.(eg csv,json etc)
# 2. File path of data set: Tells where the data is stored.
# * CSV- Comma Separated Values.

# %%
# importing dataset

import pandas as pd
data = pd.read_csv('/content/Automobile.csv')

# %% [markdown]
# **Importing CSV into python:**
#
# * With header:
# import pandas as pd
# data = pd.read_csv('path')
#
# * Without header:
# import pandas as pd
# url = "any url which has dataset"
# data = pd.read_csv('url', header = None)
#
# * We can read data as url/ path.

# %% [markdown]
# **Printing dataframe in Python:**
# * 'df' prints entire dataframe(not reccommended for large datasets).
# * 'df.head(n) to show first n rows of data frame.
# * 'df.tail(n) to show bottom n rows of data frame.

# %%
#printing first 5 rows
data.head(5)
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 2         plymouth satellite  18.0          8         318.0       150.0
# 3              amc rebel sst  16.0          8         304.0       150.0
# 4                ford torino  17.0          8         302.0       140.0
#
#    weight  acceleration  model_year origin
# 0    3504          12.0          70    usa
# 1    3693          11.5          70    usa
# 2    3436          11.0          70    usa
# 3    3433          12.0          70    usa
# 4    3449          10.5          70    usa

# %%
#printing last 3 rows
data.tail(3)
# Out:
#               name   mpg  cylinders  displacement  horsepower  weight  \
# 395  dodge rampage  32.0          4         135.0        84.0    2295
# 396    ford ranger  28.0          4         120.0        79.0    2625
# 397     chevy s-10  31.0          4         119.0        82.0    2720
#
#      acceleration  model_year origin
# 395          11.6          82    usa
# 396          18.6          82    usa
# 397          19.4          82    usa

# %% [markdown]
# **Adding headers:**
# * Replace default header (by df.columns = headers)

# %% [markdown]
# **Exporting a Pandas dataframe to CSV:**
# * We can export a pandas file to csv by preserving progress anytime by saving modified dataset using path="...."
# * Or by syntax: df.to_csv(path). Whatever may be the file format we need to follow the following syntax:
# to read: pd.read_json()
# to save/export: df.to_json()
# * Only difference is file format, where we need to replace the format we want to.

# %% [markdown]
# **Analyzing data in python:**
# * We need to check:
# 1. Data types
# 2. Data distribution
# in order to get overview about the dataset.

# %% [markdown]
# **Data types:**
#
#
#
# * Numbers & Strings->
# in pandas: object, native python: string
# * Numeric characters-> in pandas: int64, native python: int
#
# * Decimals-> in pandas: float64, python: float
# * Time data-> pandas: datetime64, timedelta[ns], python: N/A (but see the datetime module in python's standard library.)
#
# We need to check data types for:
# * Potential info and type mismatch.
# * Compatability with python methods.
#
#
# * In pandas, we use 'dataframe.dtypes' to check data types.
# * df.dtypes

# %%
#checking data types
data.dtypes
# Out:
# name             object
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# dtype: object

# %% [markdown]
# df.describe()->returns a statistical summary of dataset.
# df.describe(include="all")->provides full summary statistics.

# %%
#statistical summary of dataset
data.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
#full summary
data.describe(include="all")
# Out:
#               name         mpg   cylinders  displacement  horsepower  \
# count          398  398.000000  398.000000    398.000000  392.000000
# unique         305         NaN         NaN           NaN         NaN
# top     ford pinto         NaN         NaN           NaN         NaN
# freq             6         NaN         NaN           NaN         NaN
# mean           NaN   23.514573    5.454774    193.425879  104.469388
# std            NaN    7.815984    1.701004    104.269838   38.491160
# min            NaN    9.000000    3.000000     68.000000   46.000000
# 25%            NaN   17.500000    4.000000    104.250000   75.000000
# 50%            NaN   23.000000    4.000000    148.500000   93.500000
# 75%            NaN   29.000000    8.000000    262.000000  126.000000
# max            NaN   46.600000    8.000000    455.000000  230.000000
#
#              weight  acceleration  model_year origin
# count    398.000000    398.000000  398.000000    398
# ...

# %% [markdown]
# Unique->No. Of distinct objects in the column.
# Top->Most frequently occuring object.
# Frequent->No. of times the top object appears in the column.
# NAN-> not a number.

# %% [markdown]
# df.info()->provides concise summary of dataframe.
#
#
# * Prints info about data frame including index data type and columns non-null values and memory usage.

# %%
#concise summary
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          398 non-null    object
#  1   mpg           398 non-null    float64
#  2   cylinders     398 non-null    int64
#  3   displacement  398 non-null    float64
#  4   horsepower    392 non-null    float64
#  5   weight        398 non-null    int64
#  6   acceleration  398 non-null    float64
#  7   model_year    398 non-null    int64
#  8   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB
